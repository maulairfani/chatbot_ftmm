# %%
import pandas as pd

# %%
data = pd.read_csv("dataclean1.csv", sep=';').iloc[:, 1:]

# %%
for f in data["file_name"]:
    print(f)
# Out:
# ADVANCED MANUFACTURING AND COMPUTATIONAL APPROACH.txt
# Aktivitas Mahasiswa FTMM.txt
# Alur Pendaftaran Online Mahasiswa Baru.txt
# Alur Pengajuan Legalisir atau Transkrip KHS.txt
# Alur Pengajuan SKMA.txt
# Alur Pengajuan Surat Keterangan.txt
# Alur Pengajuan Surat Rekomendasi.txt
# Aturan Berprilaku.txt
# BANGGA EV Charging Station Ikuti ASSIE 2023.txt
# Beasiswa.txt
# BEM FTMM.txt
# Bentuk Semangat Berwirausaha Melalui Dana Usaha.txt
# bentuk-semangat-berwirausaha-melalui-dana-usaha.txt
# Biaya Pendaftaran.txt
# BLM FTMM.txt
# Brosur FTMM.txt
# Buku-Pedoman-Berperilaku-Civitas-Academica-UNAIR.pdf
# CAMENO 2023 - Kehangatan Dalam Kekeluargaan Prodi Nanoteknologi.txt
# DATA-DRIVEN DECISION SUPPORT SYSTEM.txt
# Daya Tampung Doktor TAHUN AKADEMIK 20232024.csv
# Daya Tampung Magister TAHUN AKADEMIK 20232024.csv
# Daya Tampung Profesi TAHUN AKADEMIK 20232024.csv
# Delegasi FTMM Ikuti Program WUACD di Malaysia.txt
# Desa Binaan.txt
# ...
