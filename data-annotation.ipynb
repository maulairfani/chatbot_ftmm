# %%
import json
from langchain.vectorstores import Chroma
from langchain.embeddings import OpenAIEmbeddings
import chromadb
import streamlit as st
import pandas as pd
from tqdm import tqdm
import google.generativeai as genai
genai.configure(api_key=st.secrets["google_api_key"])

# %%
with open("intentsFTMM.json", "r", encoding="utf-8") as f:
    data = json.load(f)["intents"][1:]

# %%
client = chromadb.PersistentClient("knowledge_ftmm")
embed = OpenAIEmbeddings(openai_api_key=st.secrets["openai_key"])
docsearch = Chroma(persist_directory="knowledge_ftmm", collection_name="ftmm", embedding_function=embed)
print(f"There are {docsearch._collection.count()} chunks of documents in collection")
# Out:
# There are 217 chunks of documents in collection

# %%
def embed_fn(text):
    return genai.embed_content(model="models/embedding-001", content=text, task_type="retrieval_document")["embedding"]

# %%
i = 55
print(data[i]["patterns"][0])
# embedding = embed_fn("Siapa dekan FTMM?")
# Out:
# Kelompok riset renewable and Sustainable Energy Tecnology bergerak di bidang apa?

# %%
contexts = docsearch.similarity_search(data[i]["patterns"][0], k=2)
[c.metadata for c in contexts]
# Out:
# [{'source': 'knowledges\\RENEWABLE AND SUSTAINABLE ENERGY TECHNOLOGY.txt'},
#  {'source': 'knowledges\\Penerapan Nanoteknologi Dalam Pengembangan Energi Biomassa.txt'}]

# %%
tags = [data[i]['tag'] for i in range(len(data))]
for i, t in enumerate(tags):
    print(i, t)
# Out:
# 0 Pengenalan FTMM
# 1 Lokasi FTMM
# 2 Informasi Kontak
# 3 Sejarah FTMM
# 4 Prodi FTMM
# 5 Kepimpinan FTMM
# 6 Kontribusi FTMM
# 7 Gelar Sarjana FTMM
# 8 Identitas Bendera FTMM
# 9 Identitas Logo FTMM
# 10 Visi FTMM
# 11 Misi FTMM
# 12 Visi RN
# 13 Misi RN
# 14 Visi TE
# 15 Misi TE
# 16 Visi TI
# 17 Misi TI
# 18 Visi TRKB
# 19 Misi TRKB
# 20 Visi TSD
# 21 Misi TSD
# 22 Pendaftaran
# 23 Organisasi
# 24 BEM FTMM
# 25 BLM FTMM
# 26 Koordinator Prodi TSD
# 27 Koordinator Prodi TE
# 28 Koordinator Prodi TRKB
# 29 Koordinator Prodi TI
# 30 Koordinator Prodi RN
# 31 Tenaga kependidikan
# 32 Kelompok penelitian
# 33 Visi F&E Nanotechnology
# 34 Hasil F&E Nanotechnology
# 35 Publikasi F&E Nanotechnology
# 36 Sumber Dana F&E Nanotechnology
# 37 Visi Nanotechnology & Nanomedicine
# 38 Hasil Nanotechnology & Nanomedicine
# 39 Sumber Dana Nanotechnology & Nanomedicine
# 40 HFS Enginering
# 41 Ruang lingkup HFS Enginering
# 42 Sumber Dana HFS Enginering
# 43 AMC Research
# 44 Ruang lingkup AMC Research
# 45 Sumber dana AMC Research
# 46 DDSS Research
# 47 Topik DDSS Research
# 48 Robotics & Mechatronics
# 49 Bidang Robotics & Mechatronics
# 50 Sumber Dana Robotics & Mechatronics
# 51 DH,CL,IS Research
# 52 Bidang DH,CL,IS Research
# 53 Sumber Dana DH,CL,IS Research
# 54 Publikasi DH,CL,IS Research
# 55 R & SE Technology
# 56 Bidang R & SE Technology
# 57 IE & C Engineering
# 58 Bidang IE & C Engineering
# 59 Fasilitas IE & C Engineering
# 60 Sumber Dana IE & C Engineering

# %%
from langchain.document_loaders import DirectoryLoader
loader = DirectoryLoader("knowledges")
docs = loader.load()

# %%
for i in range(len(docs)):
    print(i, docs[i].metadata["source"][11:])
# Out:
# 0 ADVANCED MANUFACTURING AND COMPUTATIONAL APPROACH.txt
# 1 Aktivitas Mahasiswa FTMM.txt
# 2 Alur Pendaftaran Online Mahasiswa Baru.txt
# 3 Alur Pengajuan Legalisir atau Transkrip KHS.txt
# 4 Alur Pengajuan SKMA.txt
# 5 Alur Pengajuan Surat Keterangan.txt
# 6 Alur Pengajuan Surat Rekomendasi.txt
# 7 Aturan Berprilaku.txt
# 8 BANGGA EV Charging Station Ikuti ASSIE 2023.txt
# 9 Beasiswa.txt
# 10 BEM FTMM.txt
# 11 Bentuk Semangat Berwirausaha Melalui Dana Usaha.txt
# 12 bentuk-semangat-berwirausaha-melalui-dana-usaha.txt
# 13 Biaya Pendaftaran.txt
# 14 BLM FTMM.txt
# 15 Brosur FTMM.txt
# 16 Buku-Pedoman-Berperilaku-Civitas-Academica-UNAIR.pdf
# 17 CAMENO 2023 - Kehangatan Dalam Kekeluargaan Prodi Nanoteknologi.txt
# 18 DATA-DRIVEN DECISION SUPPORT SYSTEM.txt
# 19 Daya Tampung Doktor TAHUN AKADEMIK 20232024.csv
# 20 Daya Tampung Magister TAHUN AKADEMIK 20232024.csv
# 21 Daya Tampung Profesi TAHUN AKADEMIK 20232024.csv
# 22 Delegasi FTMM Ikuti Program WUACD di Malaysia.txt
# 23 Desa Binaan.txt
# 24 DIGITAL HEALTH, COMPUTATIONAL LEARNING, INTELLIGENT SYSTEMS.txt
# 25 Digitalisasi UMKM dan Pendidikan Berkualitas di Dusun Kepetingan.txt
# 26 Education For Life dalam Mengatasi Dampak Buruk TPA Keputih.txt
# 27 fasilitas-penelitian.txt
# 28 fasilitas-penunjang-ftmm.txt
# 29 FOOD AND ENVIRONMENT NANOTECHNOLOGY.txt
# 30 FTMM Perkuat Kerjasama dengan Kampus – Kampus Terbaik Thailand di bidang Materials Engineering, Nanoengineering, dan Robotics.txt
# 31 FTMM Raih Best Community Engagement pada InACE di Malaysia.txt
# 32 FTMM Raih Juara II Terbaik dalam Ajang Website Award 2023 UNAIR.txt
# 33 FTMM Sumbangkan Sepeda Listrik Dalam Pengmas Penugasan di Gili Iyang.txt
# 34 ftmm-kupas-tuntas-pro-dan-kontra-ai-dalam-perguruan-tinggi-melalui-seminar-nasional-chatgpt.txt
# 35 Himano x SDGs UNAIR Dorong Zero Waste Lifestyle.txt
# 36 HMTI UNAIR Kenalkan Pesona Teknik Industri dalam Gelar Griya.txt
# 37 HUMAN FACTOR AND SYSTEM ENGINEERING.txt
# 38 ICATAM.txt
# 39 identitas-ftmm.txt
# 40 Inovasi kolaborasi Mahasiswa FTMM, FF dan FEB UNAIR Ciptakan Produk Penangkal Kecoa.txt
# 41 INTELLIGENT POWER AND CONTROL ENGINEERING.txt
# 42 Jadwal Ujian Bidang Ilmu, Tes Kesehatan dan Wawancara Program Pendidikan Dokter Subspesialis Ilmu Kesehatan Anak Fakultas Kedokteran UNAIR Semester Genap TA 20232024.csv
# 43 jadwal-ujian-program-pasca.csv
# 44 jadwal-ujian-tahap-2-genap-2023-ppdgs-bm.txt
# 45 Karya FTMM.txt
# 46 Kembangkan Wisata, FTMM Kolaborasi dengan Bumdes Ngiroboyo Pacitan.txt
# 47 Kolaborasi Asik FTMM Clean Up Daya Dengan Trash Control Community.txt
# 48 komunitas.txt
# 49 Kuliah Tamu FTMM Gali Inspirasi MBKM ala Jerman .txt
# 50 Lakukan Benchmarking dengan Monash University dan UI, TSD Membuka Peluang Kolaborasi.txt
# 51 Lewat Synreach, Ini Pemenang Duta FTMM 2023.txt
# 52 Mengenal Inovasi Produk BANGGA EVCS dalam Event ASSIE.txt
# 53 NANOTECHNOLOGY AND NANOMEDICINE.txt
# 54 Panduan Grafis FTMM.txt
# 55 Panduan MSIB.txt
# 56 Panduan PKL.txt
# 57 Panduan Proposal Skripsi.txt
# 58 Panduan-GrafisSimpleVer.pdf
# 59 Panduan-Pendidikan-FTMM_compressed.txt
# 60 Partnership.txt
# 61 pendaftaran-mahasiswa.txt
# 62 Penerapan Nanoteknologi Dalam Pengembangan Energi Biomassa.txt
# 63 Pengabdian Masyarakat FTMM di Kampung Mangrove.txt
# 64 Pengunjung Padati Event ASSIE 2023 di Grand City.txt
# 65 petunjuk-teknis-pasca.txt
# 66 PIMNAS.txt
# 67 Pimpinan FTMM.txt
# 68 plotting-wawancara-16-desember-2023.csv
# 69 ppu-pemira-gelar-pengambilan-no-urut-arsalan-no-1-devita-no-2.txt
# 70 Prestasi Mahasiswa.txt
# 71 Prodi RN Benchmarking di BRIN, Nano Center Indonesia, UI, dan ITB.txt
# 72 profil departemen.txt
# 73 program-studi.txt
# 74 QnA.txt
# 75 registrasi_mahasiswa_2023.txt
# 76 Rekayasa Nanoteknologi.txt
# 77 rekayasa-nanoteknologi-program-studi.txt
# 78 Rencana Strategis Fakultas Teknologi Maju dan Multidisiplin.txt
# 79 Rencana Strategis.txt
# 80 RENEWABLE AND SUSTAINABLE ENERGY TECHNOLOGY.txt
# 81 renstra-bab1.pdf
# 82 research-groups.txt
# 83 Revolusi IoT dalam Limbah Industri Pabrik Tahu.txt
# 84 ROBOTICS AND MECHATRONICS.txt
# 85 Sejarah FTMM.txt
# 86 Selayang Pandang FTMM.txt
# 87 seminar-nasional-ftmm-ungkap-tantangan-etika-penggunaan-chatgpt.txt
# 88 SK-Pembentukan FTMM.txt
# 89 Skuad TSD Raih The Best Metric Perfomance diajang SATRIA DATA.txt
# 90 staf-dosen-prodi-rekayasa-nanoteknologi.txt
# 91 staf-dosen-prodi-teknik-industri.txt
# 92 staf-dosen-prodi-teknik-robotika-dan-kecerdasan-buatan.txt
# 93 staf-dosen-prodi-teknologi-sains-data.txt
# 94 Tampil pada ASSIE, FTMM Gebrak Inovasi Hebat Dukung SDGs 7 dan 8.txt
# 95 teknik-elektro-program-studi.txt
# 96 teknik-industri-program-studi.txt
# 97 Teknologi IoT dalam Efisiensi Energy Monitoring System Panel Surya.txt
# 98 Teknologi Sains Data.txt
# 99 tenaga-kependidikan.txt
# 100 Tes Bidang Ilmu.csv
# 101 Tingkatkan Kerjasama di Bidang Material dan Computer Science, FTMM Lakukan Kunjungan ke Beberapa Kampus Top Thailand.txt
# 102 Tingkatkan Kolaborasi, FTMM Lakukan Kunjungan ke Universiti Teknologi Malaysia.txt
# 103 Visi Misi.txt

# %%
corpus = pd.DataFrame({
    "id": [i for i in range(len(docs))],
    "file_name": [docs[i].metadata["source"][11:] for i in range(len(docs))],
    "content": [docs[i].page_content for i in range(len(docs))]
})

# %%
retrieval_data = pd.DataFrame({
    "id": [i for i in range(len(data))],
    "tag": [data[i]['tag'] for i in range(len(data))],
    "query": [data[i]['patterns'][0] for i in range(len(data))],
    "relevant_docs": [pd.NA for i in range(len(data))]
})
retrieval_data.to_csv("retrieval_data_unlabeled.csv", index=False)
retrieval_data.head()
# Out:
#    id               tag                                              query  \
# 0   0   Pengenalan FTMM                                        FTMM adalah
# 1   1       Lokasi FTMM                              Halo FTMM ada dimana?
# 2   2  Informasi Kontak           Apakah FTMM mempunyai akun media sosial?
# 3   3      Sejarah FTMM                      Berapa jumlah mahasiswa FTMM?
# 4   4        Prodi FTMM  Apakah ada jurusan yang hanya ada satu di Indo...
#
#   relevant_docs
# 0          <NA>
# 1          <NA>
# 2          <NA>
# 3          <NA>
# 4          <NA>

# %%
relevant_docs_list = []
for i in tqdm(range(len(retrieval_data))):
    q = retrieval_data.iloc[i]["query"]
    relevant_docs = docsearch.similarity_search(q, k=2)
    docs_title = [d.metadata["source"][11:] for d in relevant_docs]
    docs_id = [corpus[corpus["file_name"] == docs_title[i]]["id"].values[0] for i in range(len(docs_title))]
    relevant_docs_list.append(docs_id)
# Out:
# 100%|██████████| 61/61 [00:22<00:00,  2.71it/s]

# %%
retrieval_data["relevant_docs"] = relevant_docs_list

# %%
retrieval_data.to_csv("retrieval_data_labeled.csv", index=False)
retrieval_data.head()
# Out:
#    id               tag                                              query  \
# 0   0   Pengenalan FTMM                                        FTMM adalah
# 1   1       Lokasi FTMM                              Halo FTMM ada dimana?
# 2   2  Informasi Kontak           Apakah FTMM mempunyai akun media sosial?
# 3   3      Sejarah FTMM                      Berapa jumlah mahasiswa FTMM?
# 4   4        Prodi FTMM  Apakah ada jurusan yang hanya ada satu di Indo...
#
#   relevant_docs
# 0      [85, 70]
# 1      [85, 51]
# 2      [74, 34]
# 3      [70, 85]
# 4      [49, 79]

# %%
title_1_list = list()
title_2_list = list()
for i in range(len(retrieval_data)):
    title_1 = corpus[corpus["id"] == retrieval_data["relevant_docs"].iloc[i][0]]["file_name"].values[0]
    title_2 = corpus[corpus["id"] == retrieval_data["relevant_docs"].iloc[i][1]]["file_name"].values[0]
    title_1_list.append(title_1)
    title_2_list.append(title_2)

# %%
retrieval_data["title_1"] = title_1_list
retrieval_data["title_2"] = title_2_list
retrieval_data.to_csv("retrieval_data_labeled.csv", index=False)
retrieval_data.head()
# Out:
#    id               tag                                              query  \
# 0   0   Pengenalan FTMM                                        FTMM adalah
# 1   1       Lokasi FTMM                              Halo FTMM ada dimana?
# 2   2  Informasi Kontak           Apakah FTMM mempunyai akun media sosial?
# 3   3      Sejarah FTMM                      Berapa jumlah mahasiswa FTMM?
# 4   4        Prodi FTMM  Apakah ada jurusan yang hanya ada satu di Indo...
#
#   relevant_docs                                            title_1  \
# 0      [85, 70]                                   Sejarah FTMM.txt
# 1      [85, 51]                                   Sejarah FTMM.txt
# 2      [74, 34]                                            QnA.txt
# 3      [70, 85]                             Prestasi Mahasiswa.txt
# 4      [49, 79]  Kuliah Tamu FTMM Gali Inspirasi MBKM ala Jerma...
#
#                                              title_2
# 0                             Prestasi Mahasiswa.txt
# 1    Lewat Synreach, Ini Pemenang Duta FTMM 2023.txt
# 2  ftmm-kupas-tuntas-pro-dan-kontra-ai-dalam-perg...
# 3                                   Sejarah FTMM.txt
# 4                              Rencana Strategis.txt

# %%
corpus.to_csv("corpus.csv", index=False)

# %%
from langchain.chat_models import ChatOpenAI

# %%
llm = ChatOpenAI()

# %%
dir(llm)
# Out:
# ['Config',
#  'InputType',
#  'OutputType',
#  '__abstractmethods__',
#  '__annotations__',
#  '__call__',
#  '__class__',
#  '__class_getitem__',
#  '__class_vars__',
#  '__config__',
#  '__custom_root_type__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__exclude_fields__',
#  '__fields__',
#  '__fields_set__',
#  '__format__',
#  '__ge__',
#  '__get_validators__',
#  '__getattribute__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__include_fields__',
#  '__init__',
#  '__init_subclass__',
#  '__iter__',
#  '__json_encoder__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__or__',
#  '__orig_bases__',
#  '__parameters__',
#  '__post_root_validators__',
#  '__pre_root_validators__',
#  '__pretty__',
#  '__private_attributes__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__repr_args__',
#  '__repr_name__',
#  '__repr_str__',
#  '__rich_repr__',
#  '__ror__',
#  '__schema_cache__',
#  '__setattr__',
#  '__setstate__',
#  '__signature__',
#  '__sizeof__',
#  '__slots__',
#  '__str__',
#  '__subclasshook__',
#  '__try_update_forward_refs__',
#  '__validators__',
#  '__weakref__',
#  '_abatch_with_config',
#  '_abc_impl',
#  '_acall_with_config',
#  '_agenerate',
#  '_agenerate_with_cache',
#  '_all_required_field_names',
#  '_astream',
#  '_atransform_stream_with_config',
#  '_batch_with_config',
#  '_calculate_keys',
#  '_call_async',
#  '_call_with_config',
#  '_client_params',
#  '_combine_llm_outputs',
#  '_convert_input',
#  '_copy_and_set_values',
#  '_create_chat_result',
#  '_create_message_dicts',
#  '_decompose_class',
#  '_default_params',
#  '_enforce_dict_if_root',
#  '_generate',
#  '_generate_with_cache',
#  '_get_encoding_model',
#  '_get_invocation_params',
#  '_get_llm_string',
#  '_get_value',
#  '_identifying_params',
#  '_init_private_attributes',
#  '_is_protocol',
#  '_iter',
#  '_lc_kwargs',
#  '_llm_type',
#  '_stream',
#  '_transform_stream_with_config',
#  'abatch',
#  'agenerate',
#  'agenerate_prompt',
#  'ainvoke',
#  'apredict',
#  'apredict_messages',
#  'astream',
#  'astream_log',
#  'async_client',
#  'atransform',
#  'batch',
#  'bind',
#  'bind_functions',
#  'build_extra',
#  'cache',
#  'call_as_llm',
#  'callback_manager',
#  'callbacks',
#  'client',
#  'completion_with_retry',
#  'config_schema',
#  'config_specs',
#  'configurable_alternatives',
#  'configurable_fields',
#  'construct',
#  'copy',
#  'default_headers',
#  'default_query',
#  'dict',
#  'from_orm',
#  'generate',
#  'generate_prompt',
#  'get_input_schema',
#  'get_lc_namespace',
#  'get_num_tokens',
#  'get_num_tokens_from_messages',
#  'get_output_schema',
#  'get_token_ids',
#  'http_client',
#  'input_schema',
#  'invoke',
#  'is_lc_serializable',
#  'json',
#  'lc_attributes',
#  'lc_id',
#  'lc_secrets',
#  'map',
#  'max_retries',
#  'max_tokens',
#  'metadata',
#  'model_kwargs',
#  'model_name',
#  'n',
#  'openai_api_base',
#  'openai_api_key',
#  'openai_organization',
#  'openai_proxy',
#  'output_schema',
#  'parse_file',
#  'parse_obj',
#  'parse_raw',
#  'predict',
#  'predict_messages',
#  'raise_deprecation',
#  'request_timeout',
#  'schema',
#  'schema_json',
#  'stream',
#  'streaming',
#  'tags',
#  'temperature',
#  'tiktoken_model_name',
#  'to_json',
#  'to_json_not_implemented',
#  'transform',
#  'update_forward_refs',
#  'validate',
#  'validate_environment',
#  'verbose',
#  'with_config',
#  'with_fallbacks',
#  'with_listeners',
#  'with_retry',
#  'with_types']

# %%
llm.model_name
# Out:
# 'gpt-3.5-turbo'
